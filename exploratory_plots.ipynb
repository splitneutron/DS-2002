# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
modern_df = pd.read_csv("https://raw.githubusercontent.com/Guillaumeserres31/Twitter-Sentiment-Analysis-on-Generative-AI-Adoption/refs/heads/main/Dataset/GenerativeAI%20tweets.csv")

print("Modern AI Dataset Statistics:")
print(modern_df.describe())
# print("\nPre AI Dataset Statistics:")
# print(pre_df2.describe())
# Out:
# Modern AI Dataset Statistics:
#          Unnamed: 0      Tweet Id
# count  56221.000000  5.622100e+04
# mean   28110.000000  1.628960e+18
# std    16229.749079  1.689126e+16
# min        0.000000  1.517066e+18
# 25%    14055.000000  1.620891e+18
# 50%    28110.000000  1.633258e+18
# 75%    42165.000000  1.641162e+18
# max    56220.000000  1.648800e+18

# %%
modern_df.head()
# Out:
#    Unnamed: 0                   Datetime             Tweet Id  \
# 0           0  2023-04-19 21:27:19+00:00  1648800467206672384
# 1           1  2023-04-19 21:27:09+00:00  1648800425540476929
# 2           2  2023-04-19 21:26:57+00:00  1648800376479715328
# 3           3  2023-04-19 21:26:49+00:00  1648800341193027584
# 4           4  2023-04-19 21:25:00+00:00  1648799883934203905
#
#                                                 Text       Username
# 0  From Studio Gangster to Synthetic Gangster 🎤.....     resembleai
# 1  Took me some time to find this. I build this #...  devaanparbhoo
# 2  Mind blowing next wave #generativeai  platform...        timreha
# 3  Open Source Generative AI Image Specialist Sta...     VirtReview
# 4  Are you an #HR leader considering which future...      FrozeElle

# %%
modern_df['Datetime'] = pd.to_datetime(modern_df['Datetime'])
tweets_by_day = modern_df.groupby(modern_df['Datetime'].dt.date).size().reset_index(name='tweet_count')

plt.figure(figsize=(12, 6))
sns.lineplot(data=tweets_by_day, x='Datetime', y='tweet_count')
plt.title('Number of Tweets Over Time')
plt.xlabel('Date')
plt.ylabel('Number of Tweets')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
modern_df['word_count'] = modern_df['Text'].apply(lambda x: len(str(x).split()))

plt.figure(figsize=(10, 6))
sns.histplot(data=modern_df, x='word_count', bins=50, kde=True)
plt.title('Distribution of Word Count in Tweets')
plt.xlabel('Word Count')
plt.ylabel('Frequency')
plt.show()
